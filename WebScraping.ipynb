# %%
# !pip install scrapy

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/RS/NewCityScraper/NewCityScraper/scrapedData
# Out:
# /content/drive/MyDrive/RS/NewCityScraper/NewCityScraper/scrapedData

# %%
# !scrapy crawl indian_city_data_scraper -o indian_city_data.json
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# !scrapy crawl foreign_city_data_scraper -o foreign_city_data.json
# Out:
# Output hidden; open in https://colab.research.google.com to view.
